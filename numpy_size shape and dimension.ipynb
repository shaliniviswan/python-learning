# %%
import numpy as np
a=np.array([1,2,3,4])
np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
import numpy as np
a=np.array([1,2,3,4])
a+2
# Out:
# array([3, 4, 5, 6])

# %%
import numpy as np
a=np.array([1,2,3,4])
a/2
# Out:
# array([0.5, 1. , 1.5, 2. ])

# %%
import numpy as np
a=np.array([1,2,3,4])
b=np.array([5,6,7,8])
a+b
# Out:
# array([ 6,  8, 10, 12])

# %%
import numpy as np
a=np.array([1,2,3,4])
b=np.array([5,6,7,8])
a.shape
b.shape
# Out:
# (4,)

# %%
import numpy as np
m=np.array([[1,2,3],
           [4,5,6]])
m.ndim
m.shape
m.size
print(m.ndim)
print(m.shape)
print(m.size)
# Out:
# 2
# (2, 3)
# 6

# %%
import numpy as np
m=np.array([[1,2,3],
           [4,5,6]])
m[1,2]
# Out:
# 6
